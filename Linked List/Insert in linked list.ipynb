# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def TakeInput():
    inputlist = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currdata in inputlist:
        if currdata == -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head = newnode
            tail = newnode
        else:
            tail.next = newnode
            tail = newnode
    return head

def length(head):
    if head is None:
        return 0
    return 1 + length(head.next)

def insert_node_at_ith_pos_iteratively(head, i ,data):
    if i<0 or i>length(head):
        return head
    curr = head
    prev = None
    c = 0
    
    while c < i:
        prev = curr
        curr = curr.next
        c+=1
        
    newnode = Node(data)
    if prev is not None:
        prev.next = newnode
    else:
        head = prev
    newnode.next = curr
    
    return head


def insert_node_at_ith_pos_recursively(head, i ,data):
    if i<0:
        return head
    if i == 0:
        newnode = Node(data)
        newnode.next = head
        return newnode
    
    if head is None:
        return None
    
    smallhead = insert_node_at_ith_pos_recursively(head.next, i-1 ,data)
    head.next = smallhead
    return head
    
    

def printll(head):
    while head is not None:
        print(str(head.data)+'->',end="")
        head = head.next
    
    return head
    
    
    
head = TakeInput()
i = int(input())
data = int(input())
#head = insert_node_at_ith_pos_iteratively(head, i ,data)
head = insert_node_at_ith_pos_recursively(head, i ,data)
printll(head)
# Out:
# 1 2 3 4 5 6
# 0
# 2
# 2->1->2->3->4->5->6->
